# %%
import pandas as pd

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('leech_data.csv')

# %%
#get the basic infromation of the table, this is to see if all the columns are created and is of the required datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S. No                 80 non-null     int64
#  1   Species name          80 non-null     object
#  2   Link                  80 non-null     object
#  3   Protein name          80 non-null     object
#  4   Gene name             5 non-null      object
#  5   Source                80 non-null     object
#  6   SwissProt ID          0 non-null      float64
#  7   No of amino acids     0 non-null      float64
#  8   Mol. wt               0 non-null      float64
#  9   Subcellular location  1 non-null      object
#  10  Mutagenesis           0 non-null      float64
#  11  PTM                   0 non-null      float64
#  12  Modified residue      0 non-null      float64
#  13  Structure (Yes/No)    0 non-null      float64
#  14  PPD ID                0 non-null      float64
# ...

# %%
counts = df['Species name'].value_counts()
# this is to make sure that all the species name are there with the specific count value

# %%
counts
# Out:
# Species name
# Hirudo medicinalis (Medicinal leech)                                         30
# Theromyzon tessulatum (Duck leech)                                           12
# Haemadipsa sylvestris (Indian leech)                                         11
# Placobdella ornata (Turtle leech)                                             6
# Hirudinaria manillensis (Asian medical leech) (Poecilobdella manillensis)     4
# Helobdella triserialis (Leech)                                                3
# Hirudo nipponia (Korean blood-sucking leech)                                  3
# Haementeria depressa (Leech)                                                  2
# Haementeria ghilianii (Amazon leech)                                          2
# Haementeria officinalis (Mexican leech)                                       2
# Macrobdella decora (North American leech)                                     2
# Haemopis marmorata (Green horse leech)                                        1
# ...

# %%
#THis code works with the column name - need to specify with which column you need to perform the search function from
def search_dataframe(df):
    # Get the column name from the user
    column_name = input("Enter the column name to search in: ")

    # Check if the column exists in the DataFrame
    if column_name not in df.columns:
        print(f"Column '{column_name}' does not exist in the DataFrame.")
        return
    
    # Get the search value from the user
    search_value = input(f"Enter the value to search for in column '{column_name}': ")
    
    # Search for the value in the specified column
    matching_rows = df[df[column_name] == search_value]

    # Check if any matching rows were found
    if not matching_rows.empty:
        print(f"Found the following rows where {column_name} is '{search_value}':")
        print(matching_rows)
    else:
        print(f"No rows found where {column_name} is '{search_value}'.")

# Call the search function
search_dataframe(df)
# Out:
# Enter the column name to search in:  Species name
# Enter the value to search for in column 'Species name':  Hirudo medicinalis (Medicinal leech)
# Found the following rows where Species name is 'Hirudo medicinalis (Medicinal leech)':
#     S. No                          Species name    Link  \
# 0       1  Hirudo medicinalis (Medicinal leech)  P01050
# 1       2  Hirudo medicinalis (Medicinal leech)  Q25092
# 2       3  Hirudo medicinalis (Medicinal leech)  P28510
# 3       4  Hirudo medicinalis (Medicinal leech)  P21523
# 4       5  Hirudo medicinalis (Medicinal leech)  P28504
# 5       6  Hirudo medicinalis (Medicinal leech)  P28508
# 6       7  Hirudo medicinalis (Medicinal leech)  P28511
# 7       8  Hirudo medicinalis (Medicinal leech)  P09944
# 8       9  Hirudo medicinalis (Medicinal leech)  P28505
# 9      10  Hirudo medicinalis (Medicinal leech)  P28506
# 10     11  Hirudo medicinalis (Medicinal leech)  P80424
# 11     12  Hirudo medicinalis (Medicinal leech)  P81511
# ...

# %%
# this works for general search, there is no need to specify which column you need to perfrom the search function 
def search_dataframe(df):
    # Get the search value from the user
    search_value = input("Enter the value to search for: ")

    # Initialize an empty DataFrame to store matching rows
    matching_rows = pd.DataFrame()

    # Iterate through each column and search for the value
    for column in df.columns:
        matching_rows = pd.concat([matching_rows, df[df[column] == search_value]])

    # Drop duplicate rows that might occur if the search value matches in multiple columns
    matching_rows = matching_rows.drop_duplicates()

    # Check if any matching rows were found
    if not matching_rows.empty:
        print(f"Found the following rows where any column matches '{search_value}':")
        print(matching_rows)
    else:
        print(f"No rows found where any column matches '{search_value}'.")

# Call the search function
search_dataframe(df)
# Out:
# Enter the value to search for:  Medicinal
# No rows found where any column matches 'Medicinal'.
